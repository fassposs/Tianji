# %% [markdown]
# 通过modelscope 下载 internlm2-chat-7b 模型：

# %%
from modelscope import snapshot_download

# model_dir = snapshot_download('Shanghai_AI_Laboratory/internlm2-chat-7b', cache_dir='./modelscope', revision='master')

# %% [markdown]
# 加载model 和 分词器

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM 
import torch
model_path = './modelscope/Shanghai_AI_Laboratory/internlm2-chat-7b'
model = AutoModelForCausalLM.from_pretrained(model_path, trust_remote_code=True).to(torch.bfloat16).cuda()
    
tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)
